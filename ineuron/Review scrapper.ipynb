# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
#storing a url inside variable
flipkart_url = "https://www.flipkart.com/search?q=" + "samsung"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=samsung'

# %%
#opening the dedicated URL
client = uReq(flipkart_url)

# %%
client

# %%
#reading out the viewpage source from the gtlm web-page
flipkart_page = client.read()

# %%
flipkart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.47c551.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
#bs (beautiful soap) is responsible for well structring or beautifying the html content(No major differences)
flipkart_html = bs(flipkart_page,"html.parser")

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
#findall is the method present in the library of bs to find the element corresponding to their classes and ID
flipkart_html.find_all('div',{"class":"cPHDOP col-12-12"})
# Out:
# [<div class="cPHDOP col-12-12"><div class="_0BvurA"><section class="pgRLLn _2OLUF3"><div class="_3Owiq+"><div class="rgHxCQ"><span>Filters</span></div></div></section><div class="GSeM5C"><section class="Iu4qXa"><div class="WCyB2K"><span>PICK A CATEGORY</span></div><div><div class="esFpML"><span><svg class="IZmjtf zyl78N" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="S6zWo2" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="hEjLuS WyLc0s" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsung&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div><div><a class="uWfXeF" href="/mobiles-accessories/mobiles/pr?sid=tyy,4io&amp;q=samsung&amp;otracker=categorytree" title="Mobiles">Mobiles</a><a class="uWfXeF" href="/mobiles-accessories/wall-chargers/pr?sid=tyy,4mr,tp2,loq&amp;q=samsung&amp;otracker=categorytree" title="Wall Chargers">Wall Chargers</a
# ...

# %%
len(flipkart_html.find_all('div',{"class":"cPHDOP col-12-12"}))
# Out:
# 15

# %%
div_boxes = flipkart_html.find_all('div',{"class":"cPHDOP col-12-12"})

# %%
for i in div_boxes:
    print(i)
# Out:
# <div class="cPHDOP col-12-12"><div class="_0BvurA"><section class="pgRLLn _2OLUF3"><div class="_3Owiq+"><div class="rgHxCQ"><span>Filters</span></div></div></section><div class="GSeM5C"><section class="Iu4qXa"><div class="WCyB2K"><span>PICK A CATEGORY</span></div><div><div class="esFpML"><span><svg class="IZmjtf zyl78N" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="S6zWo2" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="hEjLuS WyLc0s" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsung&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div><div><a class="uWfXeF" href="/mobiles-accessories/mobiles/pr?sid=tyy,4io&amp;q=samsung&amp;otracker=categorytree" title="Mobiles">Mobiles</a><a class="uWfXeF" href="/mobiles-accessories/wall-chargers/pr?sid=tyy,4mr,tp2,loq&amp;q=samsung&amp;otracker=categorytree" title="Wall Chargers">Wall Chargers</a>
# ...

# %%
div_boxes[1]
# Out:
# <div class="cPHDOP col-12-12"><div class="_75nlfW"><div data-id="MOBGYBAVSDFYZFNY" style="width:25%"><div class="slAVV4"><a class="VJA3rP" href="/samsung-galaxy-f15-5g-groovy-violet-128-gb/p/itmd0aaf528709de?pid=MOBGYBAVSDFYZFNY&amp;lid=LSTMOBGYBAVSDFYZFNY0YSXRQ&amp;marketplace=FLIPKART&amp;q=samsung&amp;store=search.flipkart.com&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=en_VX_XpcbJ63F6VhDDALREtp-XyTCQyxz5a7Jagt9P8jeHoRUyCJWTmv5wZbSVFwH7MmlrbhqS5bfPaOnbVM7NFPUFjCTyOHoHZs-Z5_PS_w0%3D&amp;ppt=None&amp;ppn=None&amp;ssid=dajb3f05zk0000001714735861767&amp;qH=fe546279a62683de" rel="noopener noreferrer" target="_blank"><div><div><div class="_4WELSP" style="height:280px;width:200px"><img alt="SAMSUNG Galaxy F15 5G (Groovy Violet, 128 GB)" class="DByuf4" loading="eager" src="https://rukminim2.flixcart.com/image/612/612/xif0q/mobile/l/v/4/galaxy-f15-5g-sm-e156b-samsung-original-imagyhkbkdy56zej.jpeg?q=70"/></div></div></div><div class="oUss6M PbRKsR"><div class="+7E521"><svg cl
# ...

# %%
Box = div_boxes[1]

# %%
Box.div.div.div.a["href"]
# Out:
# '/samsung-galaxy-f15-5g-groovy-violet-128-gb/p/itmd0aaf528709de?pid=MOBGYBAVSDFYZFNY&lid=LSTMOBGYBAVSDFYZFNY0YSXRQ&marketplace=FLIPKART&q=samsung&store=search.flipkart.com&srno=s_1_1&otracker=search&fm=organic&iid=en_VX_XpcbJ63F6VhDDALREtp-XyTCQyxz5a7Jagt9P8jeHoRUyCJWTmv5wZbSVFwH7MmlrbhqS5bfPaOnbVM7NFPUFjCTyOHoHZs-Z5_PS_w0%3D&ppt=None&ppn=None&ssid=dajb3f05zk0000001714735861767&qH=fe546279a62683de'

# %%
product_link_= "https://www.flipkart.com"+Box.div.div.a['href']

# %%
product_link_
# Out:
# 'https://www.flipkart.com/samsung-galaxy-f15-5g-groovy-violet-128-gb/p/itmd0aaf528709de?pid=MOBGYBAVSDFYZFNY&lid=LSTMOBGYBAVSDFYZFNY0YSXRQ&marketplace=FLIPKART&q=samsung&store=search.flipkart.com&srno=s_1_1&otracker=search&fm=organic&iid=en_VX_XpcbJ63F6VhDDALREtp-XyTCQyxz5a7Jagt9P8jeHoRUyCJWTmv5wZbSVFwH7MmlrbhqS5bfPaOnbVM7NFPUFjCTyOHoHZs-Z5_PS_w0%3D&ppt=None&ppn=None&ssid=dajb3f05zk0000001714735861767&qH=fe546279a62683de'

# %%
PL = uReq(product_link_)

# %%
PL

# %%
PL.encoding='utf-8'

# %%
prod_html = bs(PL, "html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
len(prod_html.find_all("div",{"class":"ZmyHeo"}))
# Out:
# 10

# %%
comment_boxes = prod_html.find_all("div",{"class":"ZmyHeo"})

# %%
comment_boxes[0]
# Out:
# <div class="ZmyHeo"><div><div class="">Good for normal use <br>Good camera<br/>Negative  is 216g weight</br></div><span class="wTYmpv"><span>READ MORE</span></span></div></div>

# %%
names = prod_html.find_all("p",{"class":"_2NsDsF AwS1CA"})

# %%
len(names)
# Out:
# 10

# %%
names[0]
# Out:
# <p class="_2NsDsF AwS1CA">Ajeesh S</p>

# %%
names
# Out:
# [<p class="_2NsDsF AwS1CA">Ajeesh S</p>,
#  <p class="_2NsDsF AwS1CA">Saikrishna Bojjankula</p>,
#  <p class="_2NsDsF AwS1CA">Aditya LSR</p>,
#  <p class="_2NsDsF AwS1CA">Muhammed Yasar</p>,
#  <p class="_2NsDsF AwS1CA">Jasvir  Singh</p>,
#  <p class="_2NsDsF AwS1CA">Jiban Khatua</p>,
#  <p class="_2NsDsF AwS1CA">deepak swami</p>,
#  <p class="_2NsDsF AwS1CA">Milan Sarkar</p>,
#  <p class="_2NsDsF AwS1CA">Kallol Halder</p>,
#  <p class="_2NsDsF AwS1CA">Flipkart Customer</p>]

# %%
for i in range (len(names)):
    print(names[i].text)
# Out:
# Ajeesh S
# Saikrishna Bojjankula
# Aditya LSR
# Muhammed Yasar
# Jasvir  Singh
# Jiban Khatua
# deepak swami
# Milan Sarkar
# Kallol Halder
# Flipkart Customer

# %%
comment_boxes
# Out:
# [<div class="ZmyHeo"><div><div class="">Good for normal use <br>Good camera<br/>Negative  is 216g weight</br></div><span class="wTYmpv"><span>READ MORE</span></span></div></div>,
#  <div class="ZmyHeo"><div><div class="">Nice 🙂 budget phone searching for glass and back cover 📔</div><span class="wTYmpv"><span>READ MORE</span></span></div></div>,
# ...

# %%
ratings = prod_html.find_all("div",{"class":"XQDdHH Ga3i8K"})

# %%
ratings
# Out:
# [<div class="XQDdHH Ga3i8K">4<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH Ga3i8K">5<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH Ga3i8K">5<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH Ga3i8K">5<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH Ga3i8K">4<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH Ga3i8K">4<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH Ga3i8K">5<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH Ga3i8K">5<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH Ga3i8K">3<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH Ga3i8K">5<img class="Rza2QY" src="..."/></div>]

# %%
for i in range (len(ratings)):
    print(ratings[i].text)
# Out:
# 4
# 5
# 5
# 5
# 4
# 4
# 5
# 5
# 3
# 5

# %%
comment_boxes
# Out:
# [<div class="ZmyHeo"><div><div class="">Good for normal use <br>Good camera<br/>Negative  is 216g weight</br></div><span class="wTYmpv"><span>READ MORE</span></span></div></div>,
#  <div class="ZmyHeo"><div><div class="">Nice 🙂 budget phone searching for glass and back cover 📔</div><span class="wTYmpv"><span>READ MORE</span></span></div></div>,
# ...

# %%
for i in comment_boxes:
    print(i.text)
# Out:
# Good for normal use Good cameraNegative  is 216g weightREAD MORE
# Nice 🙂 budget phone searching for glass and back cover 📔READ MORE
# Amazing phone at this price range. Violet doesn't look as bad as it looks in the image.Pros-1. Price 12k- steal deal for below features2. Amoled screen- Not many phones have this in this price.3. Android 14 OOTB.4. 4 years OS updates, which is up to Android 18 and 5 years security updates. Just wow.5. One UI 6.1 and not One UI core. Mind-blowing.6. Got charger at Rs.300 only7. 6000 mAh battery8. 4GB Ram variant expandable 4GB more total 8GB. So this is enough.9. Full HD+Cons- at t...READ MORE
# Best phone for this price with amoled display and 6000 mah batterAnd 4 years os updateWe can use this phone for 5 years without any problem 100% trustlyBest phoneREAD MORE
# Phone is awesome in all cases like looks camera quality display but lags in performanceREAD MORE
# Awesome Hai yarSamsung all time favoriteWorth it.READ MORE
# Good phoneREAD MORE
# ...

# %%
review = prod_html.find_all('p',{"class":"z9E0IG"})

# %%
review
# Out:
# [<p class="z9E0IG">Nice product</p>,
#  <p class="z9E0IG">Just wow!</p>,
#  <p class="z9E0IG">Mind-blowing purchase</p>,
#  <p class="z9E0IG">Perfect product!</p>,
#  <p class="z9E0IG">Pretty good</p>,
#  <p class="z9E0IG">Really Nice</p>,
#  <p class="z9E0IG">Great product</p>,
#  <p class="z9E0IG">Terrific</p>,
#  <p class="z9E0IG">Just okay</p>,
#  <p class="z9E0IG">Classy product</p>]

# %%
for i in review:
    print(i.text)
# Out:
# Nice product
# Just wow!
# Mind-blowing purchase
# Perfect product!
# Pretty good
# Really Nice
# Great product
# Terrific
# Just okay
# Classy product

# %%
for i in prod_html:
    print(i)
# Out:
# html
# ...

# %%
prod_html.div.div
# Out:
# <div><div class="krHvwW"><div class="J+HqMZ"><div class="LOe-Xr"></div><div class="Ja1j8k"><div class="ngOQ7L"><div class="F9+fd2"><a href="/"><img alt="Flipkart" class="W5mR4e" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a><a class="MwbhDR" href="/plus">Explore<!-- --> <span class="s4NJ5L">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a></div></div><div class="kRd8Cs"><form action="/search" class="Hy6F9O header-form-search" method="GET"><div class="col-12-12 BnmXvV"><div class="MoPwtI"><input autocomplete="off" class="zDPmFV" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value=""/></div><button class="MJG8Up" type="submit"><svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg"><g fill="#2874F1" fill-rule="evenodd"><path cla
# ...
