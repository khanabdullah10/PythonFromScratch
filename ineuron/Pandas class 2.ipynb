# %%
import pandas as pd

# %%
pd.DataFrame({ 'col1': [1,2,3,4] ,
               'col2': [25,10,11,12] ,
               'col3': "Khan Abdullah Ubaid Ahmed".split()    
})
# Out:
#    col1  col2      col3
# 0     1    25      Khan
# 1     2    10  Abdullah
# 2     3    11     Ubaid
# 3     4    12     Ahmed

# %%
df = pd.DataFrame({ 'col1': [1,2,3,4] ,
               'col2': [25,10,11,12] ,
               'col3': "Khan Abdullah Ubaid Ahmed".split()    
})

# %%
"Khan Abdullah Ubaid Ahmed".split()
# Out:
# ['Khan', 'Abdullah', 'Ubaid', 'Ahmed']

# %%
df['col4'] = df['col1']**2

# %%
df
# Out:
#    col1  col2      col3  col4
# 0     1    25      Khan     1
# 1     2    10  Abdullah     4
# 2     3    11     Ubaid     9
# 3     4    12     Ahmed    16

# %%
def  test(a):
    return a**2

# %%
df['col_4'] = df['col1'].apply(test)

# %%
df
# Out:
#    col1  col2      col3  col4  col_4
# 0     1    25      Khan     1      1
# 1     2    10  Abdullah     4      4
# 2     3    11     Ubaid     9      9
# 3     4    12     Ahmed    16     16

# %%
df['col5']=df['col3'].str[0]

# %%
df
# Out:
#    col1  col2      col3  col4  col_4 col5
# 0     1    25      Khan     1      1    K
# 1     2    10  Abdullah     4      4    A
# 2     3    11     Ubaid     9      9    U
# 3     4    12     Ahmed    16     16    A

# %%
def  test1(a):
    if(a == 's'):
        return a
    else:
        return 'z'

# %%
df['col6'] = df['col3'].apply(test1)

# %%
df
# Out:
#    col1  col2      col3  col4  col_4 col5 col6
# 0     1    25      Khan     1      1    K    z
# 1     2    10  Abdullah     4      4    A    z
# 2     3    11     Ubaid     9      9    U    z
# 3     4    12     Ahmed    16     16    A    z

# %%
df['col_6']=df['col5'].apply(lambda a : a if a == 's' else 'z')

# %%
df
# Out:
#    col1  col2      col3  col4  col_4 col5 col6 col_6
# 0     1    25      Khan     1      1    K    z     z
# 1     2    10  Abdullah     4      4    A    z     z
# 2     3    11     Ubaid     9      9    U    z     z
# 3     4    12     Ahmed    16     16    A    z     z

# %%
df['col7'] = df['col3'].apply(len)

# %%
df
# Out:
#    col1  col2      col3  col4  col_4 col5 col6 col_6  col7
# 0     1    25      Khan     1      1    K    z     z     4
# 1     2    10  Abdullah     4      4    A    z     z     8
# 2     3    11     Ubaid     9      9    U    z     z     5
# 3     4    12     Ahmed    16     16    A    z     z     5

# %%
import math

# %%
df['col8']= df['col2'].apply(math.log)

# %%
df
# Out:
#    col1  col2      col3  col4  col_4 col5 col6 col_6  col7      col8
# 0     1    25      Khan     1      1    K    z     z     4  3.218876
# 1     2    10  Abdullah     4      4    A    z     z     8  2.302585
# 2     3    11     Ubaid     9      9    U    z     z     5  2.397895
# 3     4    12     Ahmed    16     16    A    z     z     5  2.484907

# %%
#numeric  python
import numpy as np
