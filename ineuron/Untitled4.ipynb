# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 5C8B-CE85
#
#  Directory of C:\Users\khana
#
# 28-11-2023  11:59    <DIR>          .
# 07-11-2023  14:50    <DIR>          ..
# 07-11-2023  15:46    <DIR>          .anaconda
# 15-11-2023  22:50    <DIR>          .android
# 28-11-2023  00:06    <DIR>          .astropy
# 08-11-2023  22:56    <DIR>          .cache
# 07-11-2023  15:46    <DIR>          .conda
# 07-11-2023  15:47                25 .condarc
# 07-11-2023  15:46    <DIR>          .continuum
# 28-11-2023  11:59    <DIR>          .ipynb_checkpoints
# 07-11-2023  15:49    <DIR>          .ipython
# 07-11-2023  15:47    <DIR>          .jupyter
# 14-11-2023  17:31    <DIR>          .matplotlib
# 15-11-2023  22:47    <DIR>          .rest-client
# 26-11-2023  19:15    <DIR>          .streamlit
# 07-11-2023  00:34    <DIR>          .vscode
# 07-11-2023  00:50             6,912 -1.14-windows.xml
# 25-11-2023  12:45    <DIR>          4th - year Project
# ...

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Survived'].head(10)
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# 5    0
# 6    0
# 7    0
# 8    1
# 9    1
# Name: Survived, dtype: int64

# %%
df['sonakshi'] = None

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 13)
